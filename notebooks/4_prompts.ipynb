# %% [markdown]
# # prompts in langraph

# %%
import os

from dotenv import load_dotenv

load_dotenv()

if os.environ["GOOGLE_API_KEY"]:
    print("GOOGLE_API_KEY is set")
else:
    raise ValueError("GOOGLE_API_KEY is not set")
# Out:
# GOOGLE_API_KEY is set

# %%
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    temperature=1.0,  # Gemini 3.0+ defaults to 1.0
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)
# Out:
# c:\Users\TUSHAR\Desktop\langraph learnings\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
from langchain_core.prompts import ChatPromptTemplate

my_prompt = ChatPromptTemplate.from_messages(
    [
     ("system","you are a helpful assistant that helps to create post for a social media platforms "),
     ("human","i want to create a post about {topic}")
    ]
)

# %%
# prompt_filled = my_prompt.invoke({"topic":"about the importance of data privacy in digital age"})

# %%
# model.invoke(prompt_filled)
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Here are a few options tailored for different social media platforms, ranging from professional to casual. Choose the one that best fits your audience!\n\n---\n\n### Option 1: LinkedIn (Professional & Thought Leadership)\n**Best for:** B2B, tech professionals, and business networks.\n\n**Caption:**\nIn today’s connected world, data is often called "the new oil." But while companies use it to fuel innovation, how often do we stop to think about the cost to our personal privacy? 🔒\n\nEvery click, search, and download leaves a digital footprint. Data privacy isn\'t just about hiding secrets; it’s about:\n\n1️⃣ **Autonomy:** Having control over who accesses your personal life.\n2️⃣ **Security:** Protecting yourself from identity theft, scams, and cyberattacks.\n3️⃣ **Trust:** Ensuring businesses handle your information ethically and transparently.\n\nIn the digital age, protecting your data is synonymous with protecting your freedom. \n\n💡 **Q
# ...

# %% [markdown]
# ## chain with prompts

# %%
chain = my_prompt | model

# %%
chain.invoke({"topic":"about the importance of data privacy in digital age"})
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Here are a few options tailored for different social media platforms. Choose the one that best fits your target audience and platform!\n\n---\n\n### Option 1: LinkedIn (Professional, Educational & Thought-Provoking)\n\n**Caption:**\nIn the digital age, data is the new currency—and every click, search, and download leaves a footprint. 🌐💻\n\nData privacy is no longer just a technical issue; it’s a fundamental right. As our physical and digital lives continue to merge, protecting personal and corporate data is critical for identity security, financial safety, and personal autonomy.\n\nIf you aren\'t actively protecting your data, someone else might be profiting from it. \n\nHere are 3 simple habits to boost your digital privacy today:\n1️⃣ **Enable Two-Factor Authentication (2FA)** on all sensitive accounts.\n2️⃣ **Audit your app permissions**—does that mobile game really need access to your location and contacts?\n3️⃣ **Use a Password Manage
# ...
